# %%
car = 'subaru'

print("Is car == 'subaru'? I predict True.")
print(car == 'subaru')

print("\nIs car == 'audi'? I predict False.")
print(car == 'audi')
 
car = 'bmw'

print("\nIs car == 'subaru'? I predict False.")
print(car == 'subaru')

print("\nIs car == 'audi'? I predict False.")
print(car == 'audi')

car = 'bmw'

print("\nIs car == 'BMW'? I predict False.")
print(car == 'BMW')

print("\nIs car == 'bmw'? I predict True.")
print(car == 'bmw')

car = 'BMW'

print("\nIs car.lower() == 'BMW'? I predict False.")
print(car.lower() == 'BMW')

print("\nIs car.lower() == 'bmw'? I predict True.")
print(car.lower() == 'bmw')

age_1 = 12

age_2 =  21

print("\nIs age_1 > 15 and age_2 < 45? I predict False.")
print(age_1 > 15 or age_2 < 45)
print("\nIs age_1 < 15 and age_2 > 45? I predict False.")
print(age_1 < 15 and age_2 > 45)
print("\nIs age_1 > 15 or age_2 < 45? I predict True.")
print(age_1 > 15 or age_2 < 45)
print("\nIs age_1 < 15 or age_2 > 45? I predict False.")
print(age_1 < 15 or age_2 > 45)
# Out:
# Is car == 'subaru'? I predict True.
# True
#
# Is car == 'audi'? I predict False.
# False
#
# Is car == 'subaru'? I predict False.
# False
#
# Is car == 'audi'? I predict False.
# False
#
# Is car == 'BMW'? I predict False.
# False
#
# Is car == 'bmw'? I predict True.
# True
#
# Is car.lower() == 'BMW'? I predict False.
# False
#
# Is car.lower() == 'bmw'? I predict True.
# True
#
# Is age_1 > 15 and age_2 < 45? I predict False.
# True
#
# Is age_1 < 15 and age_2 > 45? I predict False.
# False
#
# Is age_1 > 15 or age_2 < 45? I predict True.
# True
#
# Is age_1 < 15 or age_2 > 45? I predict False.
# True

# %%
list_1 = ["cat", "dog", "bear"]

print(list_1)

print("cat" in list_1)

print("snake" in list_1)

print(list_1 == ["cat", "dog", "bear"])
# Out:
# ['cat', 'dog', 'bear']
# True
# False
# True

# %%
age = 19

if age >= 18:
    print("You are old enough to vote")
    print("Have you registered to vote yet?")
else:
    print("You are not old enough to vote yet.")
    print("Please register when you reach age 18.")
# Out:
# You are old enough to vote
# Have you registered to vote yet?

# %%
age = 4

if age <= 4:
    print("You get in free")
elif age <=18:
    print("Tickets are $25 a person.")
else: 
    print("Tickets are $40 a person.")
# Out:
# You get in free

# %%
age = 20

if age < 4:
    price = 0
elif age < 18:
    price = 25
elif age < 65:
    price = 40
elif age >= 65:
    price = 20

print(f"Your admission cost is ${price}.")
# Out:
# Your admission cost is $40.

# %%
requested_toppings = ['mushrooms', 'extra cheese']

if 'mushrooms' in requested_toppings:
    print('Adding mushrooms')
if 'pepperoni' in requested_toppings:
    print('Adding pepperoni')
if 'extra cheese' in requested_toppings:
    print('Adding extra cheese')

print('\n Finished making you pizza!')
# Out:
# Adding mushrooms
# Adding extra cheese
#
#  Finished making you pizza!
